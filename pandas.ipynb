# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series([23,24,25,12,32])
s1
# Out:
# 0    23
# 1    24
# 2    25
# 3    12
# 4    32
# dtype: int64

# %%
s2 = pd.Series([23,45,67,12,34],index = ['a','b','c','d','e'])
s2
# Out:
# a    23
# b    45
# c    67
# d    12
# e    34
# dtype: int64

# %%
s3 = pd.Series([23,45,67,12,34],index = ['a','b','c','d','e'],dtype = 'float')
s3
# Out:
# a    23.0
# b    45.0
# c    67.0
# d    12.0
# e    34.0
# dtype: float64

# %%
s3['a']
# Out:
# 23.0

# %% [markdown]
# ### creation of Series using dictionary

# %%
s4 = pd.Series({'a':65,'b':43})
s4
# Out:
# a    65
# b    43
# dtype: int64

# %% [markdown]
# ### DataFrame

# %%
d1 = pd.DataFrame([43,54,65,76])
d1
# Out:
#     0
# 0  43
# 1  54
# 2  65
# 3  76

# %%
d2 = pd.DataFrame([[2,3,4],[4,5,6],[1,2,3]])
d2
# Out:
#    0  1  2
# 0  2  3  4
# 1  4  5  6
# 2  1  2  3

# %%
d2 = pd.DataFrame(s2)  #converting series into dataframe
d2
# Out:
#     0
# a  23
# b  45
# c  67
# d  12
# e  34

# %%
d3  = pd.DataFrame([[2,3,4],[4,5,6],[1,2,3]],columns =['a','b','c'])
d3
# Out:
#    a  b  c
# 0  2  3  4
# 1  4  5  6
# 2  1  2  3

# %%
d3  = pd.DataFrame([[2,3,4],[4,5,6],[1,2,3]],columns =['a','b','c'],index = ['x','y','z'])
d3
# Out:
#    a  b  c
# x  2  3  4
# y  4  5  6
# z  1  2  3

# %% [markdown]
# ### creating DataFrame from list of dictionaries

# %%
dic = [{'alex':1,'joe':2},{'ema':5,'dora':10,'alice':20}]    
pd.DataFrame(dic)
# Out:
#    alex  alice  dora  ema  joe
# 0   1.0    NaN   NaN  NaN  2.0
# 1   NaN   20.0  10.0  5.0  NaN

# %% [markdown]
# ### DataFrame operations

# %%
d3
# Out:
#    a  b  c
# x  2  3  4
# y  4  5  6
# z  1  2  3

# %%
d3['a']
# Out:
# x    2
# y    4
# z    1
# Name: a, dtype: int64

# %%
d3['d']=d3['a']*d3['b']
d3
# Out:
#    a  b  c   d
# 0  2  3  4   6
# 1  4  5  6  20
# 2  1  2  3   2

# %%
pop = d3.pop('c') 
pop
# Out:
# 0    4
# 1    6
# 2    3
# Name: c, dtype: int64

# %%
d3
# Out:
#    a  b   d
# 0  2  3   6
# 1  4  5  20
# 2  1  2   2

# %%
del d3['d']

# %%
d3
# Out:
#    a  b
# 0  2  3
# 1  4  5
# 2  1  2

# %%
d3.insert(1,'name',d3['a'])
d3
# Out:
#    a  name  b  c
# 0  2     2  3  4
# 1  4     4  5  6
# 2  1     1  2  3

# %%
import numpy as np
d4 = pd.DataFrame({'abc':np.random.randint(2,6,size = (10)),'bcd':np.random.randint(4,5,size = (10)),'cde':np.random.randint(3,4,size = (10))})
d4
# Out:
#    abc  bcd  cde
# 0    5    4    3
# 1    5    4    3
# 2    2    4    3
# 3    5    4    3
# 4    4    4    3
# 5    3    4    3
# 6    5    4    3
# 7    3    4    3
# 8    5    4    3
# 9    3    4    3

# %%
d4.head()
# Out:
#    abc  bcd  cde
# 0    5    4    3
# 1    5    4    3
# 2    2    4    3
# 3    5    4    3
# 4    4    4    3

# %%
d4.tail()
# Out:
#    abc  bcd  cde
# 5    3    4    3
# 6    5    4    3
# 7    3    4    3
# 8    5    4    3
# 9    3    4    3

# %%
d4.loc[9,'cde']
# Out:
# 3

# %%
d4.loc[4:9,['abc','cde']]
# Out:
#    abc  cde
# 4    4    3
# 5    3    3
# 6    5    3
# 7    3    3
# 8    5    3
# 9    3    3

# %%
d4.loc[[3,4,7],['abc','cde']]
# Out:
#    abc  cde
# 3    5    3
# 4    4    3
# 7    3    3

# %%
d4.iloc[9,2]  #[row,column]
# Out:
# 3

# %%
d4.iloc[2:7,[0,2]]
# Out:
#    abc  cde
# 2    2    3
# 3    5    3
# 4    4    3
# 5    3    3
# 6    5    3

# %%
d4.abc
# Out:
# 0    5
# 1    5
# 2    2
# 3    5
# 4    4
# 5    3
# 6    5
# 7    3
# 8    5
# 9    3
# Name: abc, dtype: int32

# %%
d4.abc.values
# Out:
# array([5, 5, 2, 5, 4, 3, 5, 3, 5, 3])

# %%
d4['sum'] = d4.abc.values + d4.cde.values + d4.bcd.values
d4
# Out:
#    abc  bcd  cde  sum
# 0    5    4    3   12
# 1    5    4    3   12
# 2    2    4    3    9
# 3    5    4    3   12
# 4    4    4    3   11
# 5    3    4    3   10
# 6    5    4    3   12
# 7    3    4    3   10
# 8    5    4    3   12
# 9    3    4    3   10

# %%
a = [['rk',102,15000],['rama',103,20000],['krishna',104,25000]]
dfl = pd.DataFrame(a,columns = ['name','id','salary'])
dfl
# Out:
#       name   id  salary
# 0       rk  102   15000
# 1     rama  103   20000
# 2  krishna  104   25000

# %%
dfl[dfl.salary>=20000]
# Out:
#       name   id  salary
# 1     rama  103   20000
# 2  krishna  104   25000

# %%
dfl.append({'name' : 'sajan','id' : 105,'salary' : 30000},ignore_index = True)
# Out:
#       name   id  salary
# 0       rk  102   15000
# 1     rama  103   20000
# 2  krishna  104   25000
# 3    sajan  105   30000

# %%
dfl = dfl.append({'name' : np.nan,'id' : 105,'salary' : 30000},ignore_index = True)
dfl
# Out:
#       name     id   salary
# 0       rk  102.0  15000.0
# 1     rama  103.0  20000.0
# 2  krishna  104.0  25000.0
# 3      NaN  105.0  30000.0

# %%
dfl.isnull()
# Out:
#     name     id  salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3   True  False   False

# %%
dfl.isnull().sum()
# Out:
# name      1
# id        0
# salary    0
# dtype: int64

# %%
df1 = dfl.dropna()

# %%
dfl
# Out:
#       name     id   salary
# 0       rk  102.0  15000.0
# 1     rama  103.0  20000.0
# 2  krishna  104.0  25000.0
# 3      NaN  105.0  30000.0

# %%
dfl.fillna(value = 'abc')
# Out:
#       name     id   salary
# 0       rk  102.0  15000.0
# 1     rama  103.0  20000.0
# 2  krishna  104.0  25000.0
# 3      abc  105.0  30000.0

# %% [markdown]
# ### groupby

# %%
df = pd.DataFrame({'Animal' : ['Falcon', 'Falcon','Parrot', 'Parrot'],'Max Speed' : [380., 370., 24., 26.]})
df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
df_csv = pd.read_csv('product_csv.csv')
df_csv
# Out:
#    Unnamed: 0  ProductID ProductName   Cost ShippingLocation SellerName
# 0           0          1       LEDTV  32990            Delhi    ABC Pvt
# 1           1          2     Printer   5990            Delhi    ABC Pvt
# 2           2          3    Split AC  32050             Pune    XY Corp
# 3           3          4   Microwave  12670           Mumbai    PQ Corp

# %%
product_df1 = df_csv.rename(columns={'Cost':'Price','ShippingLocation':'Destination'})
product_df1
# Out:
#    Unnamed: 0  ProductID ProductName  Price Destination SellerName
# 0           0          1       LEDTV  32990       Delhi    ABC Pvt
# 1           1          2     Printer   5990       Delhi    ABC Pvt
# 2           2          3    Split AC  32050        Pune    XY Corp
# 3           3          4   Microwave  12670      Mumbai    PQ Corp

# %%
df_join1 = df_csv[['ProductID','ProductName']]
df_join2 = product_df1[['Price','Destination']]
df_join = df_join1.join(df_join2)
df_join
# Out:
#    ProductID ProductName  Price Destination
# 0          1       LEDTV  32990       Delhi
# 1          2     Printer   5990       Delhi
# 2          3    Split AC  32050        Pune
# 3          4   Microwave  12670      Mumbai

# %%
df_csv.sort_values(by = 'Cost')
# Out:
#    Unnamed: 0  ProductID ProductName   Cost ShippingLocation SellerName
# 1           1          2     Printer   5990            Delhi    ABC Pvt
# 3           3          4   Microwave  12670           Mumbai    PQ Corp
# 2           2          3    Split AC  32050             Pune    XY Corp
# 0           0          1       LEDTV  32990            Delhi    ABC Pvt

# %%
df_csv.sort_values(by = 'Cost',ascending = False)
# Out:
#    Unnamed: 0  ProductID ProductName   Cost ShippingLocation SellerName
# 0           0          1       LEDTV  32990            Delhi    ABC Pvt
# 2           2          3    Split AC  32050             Pune    XY Corp
# 3           3          4   Microwave  12670           Mumbai    PQ Corp
# 1           1          2     Printer   5990            Delhi    ABC Pvt

# %%
df_csv.sort_values(by = ['SellerName','Cost'])
# Out:
#    Unnamed: 0  ProductID ProductName   Cost ShippingLocation SellerName
# 1           1          2     Printer   5990            Delhi    ABC Pvt
# 0           0          1       LEDTV  32990            Delhi    ABC Pvt
# 3           3          4   Microwave  12670           Mumbai    PQ Corp
# 2           2          3    Split AC  32050             Pune    XY Corp

# %%
df_csv.sort_values(by = ['SellerName','Cost'],ascending = False)
# Out:
#    Unnamed: 0  ProductID ProductName   Cost ShippingLocation SellerName
# 2           2          3    Split AC  32050             Pune    XY Corp
# 3           3          4   Microwave  12670           Mumbai    PQ Corp
# 0           0          1       LEDTV  32990            Delhi    ABC Pvt
# 1           1          2     Printer   5990            Delhi    ABC Pvt

# %%
ctr = 1
for i in range (df_csv.shape[0]):
    df_csv.loc[i,['ProductID']] = ctr
    ctr = ctr + 1
df_csv
# Out:
#    Unnamed: 0  ProductID ProductName   Cost ShippingLocation SellerName
# 0           0          1       LEDTV  32990            Delhi    ABC Pvt
# 1           1          2     Printer   5990            Delhi    ABC Pvt
# 2           2          3    Split AC  32050             Pune    XY Corp
# 3           3          4   Microwave  12670           Mumbai    PQ Corp

# %%
df_csv.shape
# Out:
# (4, 6)

# %%
low = lambda x:x.lower()
df_csv['SellerName'] = df_csv['SellerName'].apply(low)
df_csv

# %%
df_excel = pd.read_excel('cik_list.xlsx')
df_excel
# Out:
#        CIK                      CONAME   FYRMO      FDATE     FORM  \
# 0     3662            SUNBEAM CORP/FL/  199803 1998-03-06  10-K405
# 1     3662            SUNBEAM CORP/FL/  199805 1998-05-15     10-Q
# 2     3662            SUNBEAM CORP/FL/  199808 1998-08-13  NT 10-Q
# 3     3662            SUNBEAM CORP/FL/  199811 1998-11-12   10-K/A
# 4     3662            SUNBEAM CORP/FL/  199811 1998-11-16  NT 10-Q
# 5     3662            SUNBEAM CORP/FL/  199811 1998-11-25   10-Q/A
# 6     3662            SUNBEAM CORP/FL/  199812 1998-12-22     10-Q
# 7     3662            SUNBEAM CORP/FL/  199812 1998-12-22     10-Q
# 8     3662            SUNBEAM CORP/FL/  199903 1999-03-31  NT 10-K
# 9     3662            SUNBEAM CORP/FL/  199905 1999-05-11     10-K
# 10    3662            SUNBEAM CORP/FL/  199905 1999-05-17  NT 10-Q
# 11    3662            SUNBEAM CORP/FL/  199906 1999-06-11     10-Q
# 12    3662            SUNBEAM CORP/FL/  199908 1999-08-16  NT 10-Q
# ...

# %%
df_json = pd.read_json('iris.json')
df_json
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-d243900ae130> in <module>()
# ----> 1 df_json = pd.read_json('iris.json')
#       2 df_json
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     364         return json_reader
#     365
# --> 366     return json_reader.read()
#     367
#     368
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     465             )
#     466         else:
# --> 467             obj = self._get_object_parser(self.data)
#     468         self.close()
#     469         return obj
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in _get_object_parser(self, json)
#     482         obj = None
#     483         if typ == 'frame':
# ...
